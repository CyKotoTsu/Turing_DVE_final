# %% [markdown]
# ### Imports

# %%
import statistacks as sts
import pickle
import matplotlib.pyplot as plt
import seaborn
import numpy as np

# %%
file = '/Users/chengyouyu/Desktop/Gastrulation/final_stuff/initializers/inits/data_dve_42.npy'
v_lst = sts.plot_v(file,None)

# %%
# count ve and epi
with open(file, 'rb') as f:
    mask_lst, x_lst, p_lst, q_lst = pickle.load(f)
ve_count = np.sum(mask_lst[-1] != 0)
epi_count = np.sum(mask_lst[-1] == 0)

print(f"Number of VE cells: {ve_count}")
print(f"Number of EPI cells: {epi_count}")
# Out:
# Number of VE cells: 96
# Number of EPI cells: 124
